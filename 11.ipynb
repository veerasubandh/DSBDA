# %%
import pandas as pd

# %%
df = pd.read_csv("tmdb_5000_movies.csv")
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
english_movies = df[df['original_language'] == 'en']
english_movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4797          0  [{"id": 10769, "name": "Foreign"}, {"id": 53, ...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
french_movies = df[df['original_language'] == 'fr']
french_movies
# Out:
#         budget                                             genres  \
# 235   97250400  [{"id": 14, "name": "Fantasy"}, {"id": 12, "na...
# 474          0  [{"id": 9648, "name": "Mystery"}, {"id": 18, "...
# 861   47000000                      [{"id": 18, "name": "Drama"}]
# 985   60000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...
# 1140  33000000  [{"id": 28, "name": "Action"}, {"id": 35, "nam...
# ...        ...                                                ...
# 4505         0  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 4609         0                     [{"id": 35, "name": "Comedy"}]
# 4615    300000  [{"id": 18, "name": "Drama"}, {"id": 53, "name...
# 4719    120000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 4739         0  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
#
#                                                homepage      id  \
# 235   http://www.asterixauxjeuxolympiques.com/index.php    2395
# ...

# %%
merged_movies = pd.concat([english_movies, french_movies])
print("\nMerged Movies (English + French):")
merged_movies
# Out:
# Merged Movies (English + French):
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4505          0  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 4609          0                     [{"id": 35, "name": "Comedy"}]
# 4615     300000  [{"id": 18, "name": "Drama"}, {"id": 53, "name...
# 4719     120000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 4739          0  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# ...

# %%
sorted_movies = df.sort_values(by='vote_average', ascending=False)
print("\nTop Movies Sorted by Customer Ratings:")
sorted_movies[['title', 'vote_average']]
# Out:
# Top Movies Sorted by Customer Ratings:
#                       title  vote_average
# 3519       Stiff Upper Lips          10.0
# 4247  Me You and Five Bucks          10.0
# 4045  Dancer, Texas Pop. 81          10.0
# 4662         Little Big Top          10.0
# 3992              Sardaarji           9.5
# ...                     ...           ...
# 3960           The Deported           0.0
# 4684         American Beast           0.0
# 3967    Four Single Fathers           0.0
# 4486       Naturally Native           0.0
# 4458    Harrison Montgomery           0.0
#
# [4803 rows x 2 columns]

# %%
transposed_data = df.transpose()
print("\nTransposed Data:")
transposed_data
# Out:
# Transposed Data:
#                                                                    0     \
# budget                                                        237000000
# genres                [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# homepage                                    http://www.avatarmovie.com/
# id                                                                19995
# keywords              [{"id": 1463, "name": "culture clash"}, {"id":...
# original_language                                                    en
# original_title                                                   Avatar
# overview              In the 22nd century, a paraplegic Marine is di...
# popularity                                                   150.437577
# production_companies  [{"name": "Ingenious Film Partners", "id": 289...
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 2009-12-10
# ...

# %%
melted_df = pd.melt(df,
                    id_vars=['title', 'original_language'],
                    value_vars=['budget', 'revenue', 'vote_average'])

print("\nMelted Data (Long Format):")
melted_df
# Out:
# Melted Data (Long Format):
#                                           title original_language  \
# 0                                        Avatar                en
# 1      Pirates of the Caribbean: At World's End                en
# 2                                       Spectre                en
# 3                         The Dark Knight Rises                en
# 4                                   John Carter                en
# ...                                         ...               ...
# 14404                               El Mariachi                es
# 14405                                 Newlyweds                en
# 14406                 Signed, Sealed, Delivered                en
# 14407                          Shanghai Calling                en
# 14408                         My Date with Drew                en
#
#            variable        value
# 0            budget  237000000.0
# 1            budget  300000000.0
# 2            budget  245000000.0
# ...

# %%
pivot_df = df.pivot_table(values='vote_average', index='original_language', aggfunc='mean')
print("\nPivoted Data (Wide Format) - Avg. Vote by Language:")
pivot_df
# Out:
# Pivoted Data (Wide Format) - Avg. Vote by Language:
#                    vote_average
# original_language
# af                     6.900000
# ar                     7.300000
# cn                     6.500000
# cs                     5.650000
# da                     7.128571
# de                     6.325926
# el                     6.900000
# en                     6.065683
# es                     6.659375
# fa                     7.375000
# fr                     6.430000
# he                     7.400000
# hi                     6.010526
# hu                     6.500000
# id                     7.400000
# is                     6.900000
# it                     7.028571
# ja                     7.050000
# ko                     6.672727
# ky                     0.000000
# nb                     6.700000
# nl                     7.175000
# no                     6.100000
# pl                     7.100000
# ps                     6.300000
# pt                     6.388889
# ...
